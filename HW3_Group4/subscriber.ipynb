# %%
import paho.mqtt.client as mqtt
from dataclasses import dataclass
import json
import redis
import time
import datetime

# %%
@dataclass
class RedisCredential:
    """
    The RedisCredential is a class used to store users data.
    """
    username: str
    password: str
    host: str
    port: str

TanguyRedis = RedisCredential(
    "default",
    "2llMg9E9AkqLcDdx6HDpLQ7nzkQKgtCC",
    "redis-17061.c300.eu-central-1-1.ec2.redns.redis-cloud.com",
    17061
)

# %%
class RedisWriter:
    """
    The RedisWriter class is used to manage the redis database.
    """

    def __init__(
        self,
        credentials
    ):
        # Create the redis client
        self.redis_client = redis.Redis(
            host=credentials.host,
            port=credentials.port,
            username=credentials.username,
            password=credentials.password
        )

        # Verify the connection
        if self.redis_client.ping():
            print("Succesfully connected to Redis")
        else:
            print("Not connected to Redis.")
        
        
    def create(
        self, 
        ts: str, 
        chunk_size_bytes: int = 4096,
        retention_hour: int = 24,
        compresses: bool = True, 
        delete_if_exists: bool = False):

        # Create the timeseries
        try:
            self.redis_client.ts().create(
                ts,
                retention_msecs=retention_hour*60*60*1000,
                chunk_size=chunk_size_bytes,
                uncompressed = not compresses
            )
        except redis.ResponseError:
            # Ignore error if the timeseries already exists
            pass
        
    
    def add(self, ts, timestamp, value):
        """Add a new value to the time series."""
        self.redis_client.ts().add(ts, timestamp, value)
    
    def get(self, ts):
        return self.redis_client.ts().get(ts)

# %%
rdwriter = RedisWriter(TanguyRedis)

# %%
client = mqtt.Client()

# %%
def on_connect(client, userdata, flags, rc):
    print(f'Connected with result code {str(rc)}')
    # Subscribe to a topic when the client connects
    client.subscribe('s329112/#')

# %%
def on_message(client, userdata, msg):
    # Decode the message
    message = msg.payload.decode()
    data = json.loads(message)

    mac_address = data['mac_address']
    timestamp = data["timestamp"]
    temperature = data['temperature']
    humidity = data['humidity']
    temperature_timeseries_name = f'{mac_address}:temperature'
    humidity_timeseries_name = f'{mac_address}:humidity'

    rdwriter.create(temperature_timeseries_name)
    rdwriter.create(humidity_timeseries_name)
    rdwriter.add(temperature_timeseries_name, timestamp, temperature)
    rdwriter.add(humidity_timeseries_name, timestamp, humidity)
    # Print the message and its topic
    print(f"Received message '{message}' on topic {msg.topic}")

# %%
client.on_connect = on_connect
client.on_message = on_message

# %%
client.connect('mqtt.eclipseprojects.io', 1883)

# Start the client loop to process network events and call the callbacks
client.loop_forever()
# Out:
# Connected with result code 0
# Succesfully connected to Redis
# Succesfully connected to Redis
# Received message '{"mac_address": "0xe45f01d8f467", "timestamp": 1736408933822, "temperature": 4, "humidity": 3}' on topic s329112
# Succesfully connected to Redis
# Succesfully connected to Redis
# Received message '{"mac_address": "0xe45f01d8f467", "timestamp": 1736408936075, "temperature": 10, "humidity": 7}' on topic s329112
# Succesfully connected to Redis
# Succesfully connected to Redis
# Received message '{"mac_address": "0xe45f01d8f467", "timestamp": 1736408938328, "temperature": 8, "humidity": 0}' on topic s329112
# Succesfully connected to Redis
# Succesfully connected to Redis
# Received message '{"mac_address": "0xe45f01d8f467", "timestamp": 1736408940581, "temperature": 4, "humidity": 2}' on topic s329112
# Succesfully connected to Redis
# Succesfully connected to Redis
# Received message '{"mac_address": "0xe45f01d8f467", "timestamp": 1736408942834, "temperature": 8, "humidity": 1}' on topic s329112
# Succesfully connected to Redis
# Succesfully connected to Redis
# Received message '{"mac_address": "0xe45f01d8f467", "timestamp": 1736408945090, "temperature": 7, "humidity": 9}' on topic s329112
# Succesfully connected to Redis
# Succesfully connected to Redis
# Received message '{"mac_address": "0xe45f01d8f467", "timestamp": 1736408947343, "temperature": 3, "humidity": 8}' on topic s329112
# Succesfully connected to Redis
# Succesfully connected to Redis
# Received message '{"mac_address": "0xe45f01d8f467", "timestamp": 1736408949596, "temperature": 10, "humidity": 1}' on topic s329112
# Succesfully connected to Redis
# Succesfully connected to Redis
# Received message '{"mac_address": "0xe45f01d8f467", "timestamp": 1736408951849, "temperature": 8, "humidity": 1}' on topic s329112
# Succesfully connected to Redis
# Succesfully connected to Redis
# Received message '{"mac_address": "0xe45f01d8f467", "timestamp": 1736408954101, "temperature": 5, "humidity": 6}' on topic s329112
# Succesfully connected to Redis
# Succesfully connected to Redis
# Received message '{"mac_address": "0xe45f01d8f467", "timestamp": 1736408956354, "temperature": 7, "humidity": 10}' on topic s329112
# Succesfully connected to Redis
# Succesfully connected to Redis
# Received message '{"mac_address": "0xe45f01d8f467", "timestamp": 1736408958607, "temperature": 10, "humidity": 10}' on topic s329112
# Succesfully connected to Redis
# Succesfully connected to Redis
# Received message '{"mac_address": "0xe45f01d8f467", "timestamp": 1736408960860, "temperature": 6, "humidity": 4}' on topic s329112
# Succesfully connected to Redis
# Succesfully connected to Redis
# Received message '{"mac_address": "0xe45f01d8f467", "timestamp": 1736408963113, "temperature": 5, "humidity": 10}' on topic s329112
# Succesfully connected to Redis
# Succesfully connected to Redis
# Received message '{"mac_address": "0xe45f01d8f467", "timestamp": 1736408965366, "temperature": 0, "humidity": 7}' on topic s329112
# Succesfully connected to Redis
# Succesfully connected to Redis
# Received message '{"mac_address": "0xe45f01d8f467", "timestamp": 1736408967618, "temperature": 1, "humidity": 5}' on topic s329112
# Succesfully connected to Redis
# Succesfully connected to Redis
# Received message '{"mac_address": "0xe45f01d8f467", "timestamp": 1736408969871, "temperature": 2, "humidity": 5}' on topic s329112
# Succesfully connected to Redis
# Succesfully connected to Redis
# Received message '{"mac_address": "0xe45f01d8f467", "timestamp": 1736408972124, "temperature": 3, "humidity": 8}' on topic s329112
# Succesfully connected to Redis
# Succesfully connected to Redis
# Received message '{"mac_address": "0xe45f01d8f467", "timestamp": 1736408974377, "temperature": 3, "humidity": 0}' on topic s329112
# Succesfully connected to Redis
# Succesfully connected to Redis
# Received message '{"mac_address": "0xe45f01d8f467", "timestamp": 1736408976630, "temperature": 0, "humidity": 4}' on topic s329112
# Succesfully connected to Redis
# Succesfully connected to Redis
# Received message '{"mac_address": "0xe45f01d8f467", "timestamp": 1736408978883, "temperature": 6, "humidity": 6}' on topic s329112
# Succesfully connected to Redis
# Succesfully connected to Redis
# Received message '{"mac_address": "0xe45f01d8f467", "timestamp": 1736408981135, "temperature": 7, "humidity": 6}' on topic s329112
# Succesfully connected to Redis
# Succesfully connected to Redis
# Received message '{"mac_address": "0xe45f01d8f467", "timestamp": 1736408983388, "temperature": 0, "humidity": 5}' on topic s329112
# Succesfully connected to Redis
# Succesfully connected to Redis
# Received message '{"mac_address": "0xe45f01d8f467", "timestamp": 1736408985641, "temperature": 10, "humidity": 10}' on topic s329112
# Succesfully connected to Redis
# Succesfully connected to Redis
# Received message '{"mac_address": "0xe45f01d8f467", "timestamp": 1736408987894, "temperature": 5, "humidity": 10}' on topic s329112
# Succesfully connected to Redis
# Succesfully connected to Redis
# Received message '{"mac_address": "0xe45f01d8f467", "timestamp": 1736408990146, "temperature": 7, "humidity": 8}' on topic s329112
# Succesfully connected to Redis
# Succesfully connected to Redis
# Received message '{"mac_address": "0xe45f01d8f467", "timestamp": 1736408992399, "temperature": 3, "humidity": 1}' on topic s329112
# Succesfully connected to Redis
# Succesfully connected to Redis
# Received message '{"mac_address": "0xe45f01d8f467", "timestamp": 1736408994652, "temperature": 2, "humidity": 10}' on topic s329112
# Succesfully connected to Redis
# Succesfully connected to Redis
# Received message '{"mac_address": "0xe45f01d8f467", "timestamp": 1736408996905, "temperature": 7, "humidity": 9}' on topic s329112
# Succesfully connected to Redis
# Succesfully connected to Redis
# Received message '{"mac_address": "0xe45f01d8f467", "timestamp": 1736408999158, "temperature": 7, "humidity": 3}' on topic s329112
# Succesfully connected to Redis
# Succesfully connected to Redis
# Received message '{"mac_address": "0xe45f01d8f467", "timestamp": 1736409001414, "temperature": 6, "humidity": 10}' on topic s329112
# Succesfully connected to Redis
# Succesfully connected to Redis
# Received message '{"mac_address": "0xe45f01d8f467", "timestamp": 1736409003667, "temperature": 5, "humidity": 6}' on topic s329112
# Succesfully connected to Redis
# Succesfully connected to Redis
# Received message '{"mac_address": "0xe45f01d8f467", "timestamp": 1736409005923, "temperature": 8, "humidity": 4}' on topic s329112
# Succesfully connected to Redis
# Succesfully connected to Redis
# Received message '{"mac_address": "0xe45f01d8f467", "timestamp": 1736409008176, "temperature": 3, "humidity": 2}' on topic s329112
# Succesfully connected to Redis
# Succesfully connected to Redis
# Received message '{"mac_address": "0xe45f01d8f467", "timestamp": 1736409010443, "temperature": 10, "humidity": 1}' on topic s329112
# Succesfully connected to Redis
# Succesfully connected to Redis
# Received message '{"mac_address": "0xe45f01d8f467", "timestamp": 1736409012697, "temperature": 6, "humidity": 6}' on topic s329112
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 4
#       1 client.connect('mqtt.eclipseprojects.io', 1883)
#       3 # Start the client loop to process network events and call the callbacks
# ----> 4 client.loop_forever()
#
# File ~/venv/lib/python3.11/site-packages/paho/mqtt/client.py:1756, in Client.loop_forever(self, timeout, max_packets, retry_first_connection)
#    1754 rc = MQTT_ERR_SUCCESS
#    1755 while rc == MQTT_ERR_SUCCESS:
# -> 1756     rc = self._loop(timeout)
#    1757     # We don't need to worry about locking here, because we've
#    1758     # either called loop_forever() when in single threaded mode, or
#    1759     # in multi threaded mode when loop_stop() has been called and
#    1760     # so no other threads can access _out_packet or _messages.
#    1761     if (self._thread_terminate is True
#    1762         and len(self._out_packet) == 0
#    1763             and len(self._out_messages) == 0):
#
# File ~/venv/lib/python3.11/site-packages/paho/mqtt/client.py:1150, in Client._loop(self, timeout)
#    1147     rlist = [self._sock, self._sockpairR]
#    1149 try:
# -> 1150     socklist = select.select(rlist, wlist, [], timeout)
#    1151 except TypeError:
#    1152     # Socket isn't correct type, in likelihood connection is lost
#    1153     return MQTT_ERR_CONN_LOST
#
# KeyboardInterrupt:

# %%
last_timestamp_ms, last_value = rdwriter.get('0xe45f01d8f467:humidity')
print(last_timestamp_ms, last_value)
last_timestamp_ms, last_value = rdwriter.get('0xe45f01d8f467:temperature')
print(last_timestamp_ms, last_value)

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=b6b1fe17-4020-4f88-867f-48004baa1058' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
